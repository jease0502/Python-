# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import re
import urllib3
urllib3.disable_warnings()
import time

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
myfont = FontProperties(fname=r'C:\\Users\\jease\\.conda\\envs\\Reptile\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf')

# %%
url = "http://book.zongheng.com/chapter/784475/44246026.html"
resp = requests.get(url,verify = False)
resp.encoding = 'utf-8'
html = BeautifulSoup(resp.text, "lxml")
print(html)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="本页版权 www.zongheng.com 纵横中文网所有。All Rights Reserved" name="copyright"/>
# <meta content="webkit" name="renderer"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://static.zongheng.com/favicon.ico" rel="shortcut icon"/>
# <title>重启修仙纪元_第001章  灵气复苏前_都市·娱乐小说阅读页 - 纵横中文网</title>
# <meta content="重启修仙纪元阅读页,第001章  灵气复苏前" name="keywords"/>
# <meta content="纵横中文网最新更新重启修仙纪元,本章内容为第001章  灵气复苏前的全文阅读页,重启修仙纪元最新章节免费阅读,页面无弹窗,访问速度快尽在纵横中文网。" name="description"/>
# <link href="//rcode.zongheng.com/v2018/css/basic.min.css" rel="stylesheet"/>
# <link href="//rcode.zongheng.com/v2018/css/reader.min.css" rel="stylesheet"/>
# <script>function rSetDef(){function a(){var key="rSet";var arr,reg=new RegExp("(^| )"+key+"=([^;]*)(;|$)");if(arr=document.cookie.match(reg)){return unescape(arr[2])}else{return null}}if(a()){return(a().split("_"))}else{return"1_3_1_14".split("_")}}</script>
# </head>
# <body _pgid="88" authorid="" authorname="" bookid="784475" bookname="重启修仙纪元" chapterdelayrelease="false" chapterid="44246026" chapterlevel="0" chaptername="第001章  灵气复苏前" class="rb_1" currentuserfactor="" donaterate="1" forumid="220048" ismemberbook="false" ismonthorderbook="" isuserdonate="true" lastchapterid="44246011" level="" logger="8000:/click/1096/9/784475/C/44246026/12468921/2018-11-18/0/chapter" monkeyid="zongheng-chapter" nextchapterid="44246032" reader="chapter" scriptsign="chapter" tomeid="1720605" userfactor="" vipuserfactor="">
# <script>document.body.className="rb_"+rSetDef()[0]</script>
# <div class="head-fixed-reader head-simple">
# <div class="wrap">
# <div class="head-top clearfix">
# <div class="logo imgbox fl"><a data-sa-d='{"click_name":"zongheng_logo","page_module":"zongheng_logo"}' href="http://www.zongheng.com"><img alt="logo" src="http://rcode.zongheng.com/v2018/images/logo.png"/></a></div>
# <form action="http://search.zongheng.com/s" method="get" name="searchForm" target="_blank">
# <div class="search-box">
# <input autocomplete="off" class="search-text fl" disableautocomplete="" name="keyword" placeholder="雪中悍刀行" type="text" value=""/>
# <input class="search-btn fr" type="submit"/>
# </div>
# </form>
# <div class="menu clearfix">
# <a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"home"}' href="http://www.zongheng.com">首页</a>
# <div class="cate tabA">
# <a href="##">分类<em class="icon"></em></a>
# <div class="tabA-float cate-cell">
# <ul>
# <li><a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"category","category_name":"奇幻玄幻","category_id":"1"}' href="http://www.zongheng.com/category/1.html">奇幻玄幻</a></li>
# <li><a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"category","category_name":"武侠仙侠","category_id":"3"}' href="http://www.zongheng.com/category/3.html">武侠仙侠</a></li>
# <li><a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"category","category_name":"历史军事","category_id":"6"}' href="http://www.zongheng.com/category/6.html">历史军事</a></li>
# <li><a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"category","category_name":"都市娱乐","category_id":"9"}' href="http://www.zongheng.com/category/9.html">都市娱乐</a></li>
# <li><a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"category","category_name":"竞技同人","category_id":"21"}' href="http://www.zongheng.com/category/21.html">竞技同人</a></li>
# <li><a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"category","category_name":"科幻游戏","category_id":"15"}' href="http://www.zongheng.com/category/15.html">科幻游戏</a></li>
# <li><a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"category","category_name":"悬疑灵异","category_id":"18"}' href="http://www.zongheng.com/category/18.html">悬疑灵异</a></li>
# <li><a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"category","category_name":"二次元","category_id":"40"}' href="http://www.zongheng.com/category/40.html">二次元</a></li>
# </ul>
# </div>
# </div>
# <a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"paihang"}' href="http://www.zongheng.com/rank.html">排行</a>
# <a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"bookStore"}' href="http://www.zongheng.com/store.html">书库</a>
# <a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"wanben"}' href="http://www.zongheng.com/store/c0/c0/b0/u0/p1/v9/s1/t0/u0/i1/ALL.html">完本</a>
# <a data-sa-d='{"click_name":"floatNav","page_module":"floatNavPage","nav_type":"authorArea"}' href="http://author.zongheng.com" target="_blank">作者专区</a>
# </div>
# <div class="pay fr">
# <a class="user_pay" data-sa-c='{"event":"clickSelf"}' data-sa-d='{"click_name":"charge"}' href="http://pay.zongheng.com" target="_blank">充值</a>
# </div>
# <div class="right-wrap-login ud_userTox">
# <div class="unlogin ud_unlogin clearfix">
# <div class="login fl"><a class="user_login" href="https://passport.zongheng.com">登录</a></div>
# <div class="regist fl"><a class="user_register" href="https://passport.zongheng.com/webreg">注册</a></div>
# </div>
# <div class="logon ud_loged clearfix" style="display:none;">
# <div class="user tabA imgbox">
# <img alt="" class="ud_avatar ud_goUsrCenter" src="http://rcode.zongheng.com/v2018/images/book.png" target="_blank"/>
# <div class="user-blank tabA-float">
# <a class="quit ud_logout" href="javascript:void(0);">退出</a>
# <div class="user-name ud_goUsrCenter"><span class="ud_nickName"></span><em class="icon"></em></div>
# <div class="user-info clearfix">
# <div class="user-info-cell ud_money">
# <span class="item_loading"></span>
# </div>
# <div class="user-info-cell ud_ticket">
# <span class="item_loading"></span>
# </div>
# <div class="user-info-cell ud_mticket">
# <span class="item_loading"></span>
# </div>
# </div>
# <a class="btn" href="http://pay.zongheng.com" target="_blank">立即充值</a>
# </div>
# </div>
# <div class="message">
# <a class="mes" data-sa-c='{"event":"clickSelf"}' data-sa-d='{"click_name":"message"}' href="http://home.zongheng.com/msgIn.do" target="_blank">消息(<span class="ud_umessage"></span>)</a>
# </div>
# <div class="shelf"><a data-sa-c='{"event":"clickSelf"}' data-sa-d='{"click_name":"shelf"}' href="http://home.zongheng.com/favoritesBook.do" target="_blank">书架</a></div>
# <div class="foot-mark tabA">
# <span class="mark clearfix">历史<em class="icon"></em></span>
# <div class="tabA-float float-mark clearfix">
# <!-- loading -->
# <div class="ud_hisloading">
# <span class="item_loading"></span>
# </div>
# <!-- 没有记录 -->
# <div class="ud_noHistory" style="display: none">
# <h2>亲爱的书友，您暂时没有阅读记录~</h2>
# <div class="tips">阅读记录只保存最近阅读的5本小说</div>
# <div class="enter"><a href="http://home.zongheng.com/favoritesBook.do" target="_blank">进入我的书架</a></div>
# </div>
# <!-- 有记录 -->
# <div class="ud_hasHistory" style="display: none"><ul class="mark-list"></ul></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- 大包 -->
# <div class="readerPageWrap">
# <div class="h20-blank"></div>
# <!-- 推广层 -->
# <div class="goodgame" data-sa-d='{"adv_type":"readPageBackgroud","adv_res":"zongheng","pos":""}'><a href="http://www.zongheng.com" target="_blank"></a></div>
# <!-- 主内容 -->
# <div class="rw_3" id="reader_warp">
# <script>document.getElementById("reader_warp").className = "rw_" + rSetDef()[1];</script>
# <!-- 1.	阅读器头部推荐位 -->
# <div class="com-recbox" data-sa-d='{"adv_type":"readPage00","adv_res":"zongheng","pos":""}'>
# <script src="http://static.zongheng.com/upload/hzds/column/240517642449.js" type="text/javascript"></script>
害，不还是被李浪他们打得……”</p><p>　　此时，高歌转过脸，看了眼正在说话的眼镜男，对方直接打了个哆嗦，嘴唇吓得发白，赶紧低下脑袋，避开了高歌那凶戾的目光。</p><p>　　等到高歌走了之后，他那两条腿还在不停发抖。</p><p>　　A座教学楼。</p><p>　　高三八班。</p><p>　　他刚走到教室门口，就听见“砰”的一声。</p><p>　　“给我滚！你们都给我滚！”</p><p>　　高歌身体猛地一震，仿佛有一只无形的手，抓住了自己的心脏。</p><p>　　稍微发力，就会将整颗心捏的粉碎。</p><p>　　孟静的声音。</p><p>　　窗户紧闭着，教室的门从里面锁上，透过窗户，能看见里面不少同学围在一起，中间却让出了一大片空间。</p><p>　　依旧是扎着马尾的孟静，不施粉黛的素颜，那精致的五官一定是上帝最骄傲的作品。上辈子多少同学叹息红颜薄命，这辈子，哪怕是鬼差来，他也要掐住对方的脖子，留下孟静。</p><p>　　去特么的天妒红颜！</p><p>　　老子第一个不服！</p><p>　　</p>
# </div>
# <!-- 订阅盒 -->
# <!-- 作者的话 -->
# <div class="authortips">
# <div class="avatar">
# <img alt="步履无声" src="http://static.zongheng.com/userimage/f8/c1/f8c1760b60b074ddd2ac68d4b29aa9c3_120_120.jpeg"/>
# <div class="avatar_b">作者的话</div>
# </div>
# <div class="con">
# <em class="arr"></em>
# <p>新书来啦！望奔走相告，记得收藏，评论哦！</p>
# </div>
# </div>
# <div class="space_h80"></div>
# <!-- 捧场按钮 -->
# <a class="big_donate" data-sa-d='{"page_module":"readPage","click_name":"donate2","book_id":"784475"}' href="javascript:void(0)"><em></em><p>捧场</p></a>
# <div class="space_h80"></div>
# <!-- 操作区 -->
# <div class="chap_btnbox">
# <a data-sa-d='{"page_module":"readPage","click_name":"catalogue2","book_id":"784475"}' href="http://book.zongheng.com/showchapter/784475.html">目录</a>
# <a data-sa-d='{"page_module":"readPage","click_name":"previous","book_id":"784475"}' href="http://book.zongheng.com/chapter/784475/44246011.html">上一章</a>
# <a class="nextchapter" data-sa-d='{"page_module":"readPage","click_name":"next","book_id":"784475"}' href="http://book.zongheng.com/chapter/784475/44246032.html">下一章</a>
# </div>
# <div class="ctrl_tips">按“键盘左键←”返回上一章   按“键盘右键→”进入下一章   按“空格键”向下滚动</div>
# <!-- 章评盒 -->
# <div class="chapter_forum" id="reader-chapterforum-wrap">
# <div class="chapter_forum_tit">
# <h3>章节评论</h3>
# <a class="chapter_forum_btn" data-sa-d='{"page_module":"readPage","click_name":"comment","book_id":"784475"}' href="javascript:void(0)">发表章评</a>
# </div>
# <div class="chapter_thread_list">
# <div class="chapter_thread">
# <ul class="forums-list" id="JthreadList"></ul>
# </div>
# </div>
# <div class="chapter_morethread">
# </div>
# </div>
# <!-- /章评盒 -->
# </div>
# <!-- /内容主盒 -->
# </div>
# <!-- /包裹层 -->
# </div>
# <!-- 控制手柄 -->
# <div class="gamepad">
# <!-- 阅读手柄，左侧目录弹出列表层 -->
# <div id="uiGPReaderAct">
# <div class="gpd_btnpal">
# <a class="chapterList" data-sa-d='{"page_module":"readPage","click_name":"catalogue","book_id":"784475"}' href="http://book.zongheng.com/showchapter/784475.html" target="_blank">目录</a>
# <a class="bookShelf" data-sa-d='{"page_module":"readPage","click_name":"shelf","book_id":"784475"}' href="javascript:void(0)">书架</a>
# <a class="bookDetail" data-sa-d='{"page_module":"readPage","click_name":"page","book_id":"784475"}' href="http://book.zongheng.com/book/784475.html" target="_blank">书页</a>
# <a class="readerSetting" data-sa-d='{"page_module":"readPage","click_name":"set","book_id":"784475"}' href="javascript:void(0)">设置</a>
# </div>
# <div class="gpd_flt_chapterlist"></div>
# <!-- 控制面板 -->
# <div class="gpd_flt_setting" data-pname="readerSetting">
# <h4>设置</h4>
# <div class="gpd_setLine gpd_setstyle">
# <div class="gpd_setName">阅读背景</div>
# <div class="gpd_setcon">
# <a class="sbs_1 active" data-style="1" href="javascript:void(0)"></a>
# <a class="sbs_2" data-style="2" href="javascript:void(0)"></a>
# <a class="sbs_3" data-style="3" href="javascript:void(0)"></a>
# <a class="sbs_4" data-style="4" href="javascript:void(0)"></a>
# <a class="sbs_5" data-style="5" href="javascript:void(0)"></a>
# <a class="sbs_6" data-style="6" href="javascript:void(0)"></a>
# <a class="sbs_7" data-style="7" href="javascript:void(0)"></a>
# <a class="sbs_8" data-style="8" href="javascript:void(0)"></a>
# </div>
# </div>
# <div class="gpd_setLine gpd_setfont">
# <div class="gpd_setName">正文字体</div>
# <div class="gpd_setcon">
# <a class="sbf_1" data-font="1" href="javascript:void(0)">宋体</a>
# <a class="sbf_2 active" data-font="2" href="javascript:void(0)">黑体</a>
# <a class="sbf_3" data-font="3" href="javascript:void(0)">微软雅黑</a>
# <a class="sbf_4" data-font="4" href="javascript:void(0)">楷体</a>
# </div>
# </div>
# <div class="gpd_setLine gpd_setsize">
# <div class="gpd_setName">字体大小</div>
# <div class="gpd_setcon">
# <div class="sbw_font">
# <a class="setfont" data-size="small" href="javascript:void(0)">A-</a>
# <div class="nowfont">16</div>
# <a class="setfont" data-size="big" href="javascript:void(0)">A+</a>
# </div>
# </div>
# </div>
# <div class="gpd_setLine gpd_setwidth">
# <div class="gpd_setName">页面宽度</div>
# <div class="gpd_setcon">
# <a class="sbw_1" data-width="1" href="javascript:void(0)">640</a>
# <a class="sbw_2" data-width="2" href="javascript:void(0)">800</a>
# <a class="sbw_3 active" data-width="3" href="javascript:void(0)">默认</a>
# <a class="sbw_4" data-width="4" href="javascript:void(0)">1280</a>
# </div>
# </div>
# <div class="gpd_btnLine">
# <button class="confirm">保存设置</button>
# <button class="reset">恢复默认</button>
# </div>
# <a class="gpd_close ui_widget_close"></a>
# </div>
# </div>
# <!-- 阅读手柄，右侧下控制按钮 -->
# <div id="uiGPUserAct">
# <div class="gpd_btnpal">
# <a class="donate" data-sa-d='{"page_module":"readPage","click_name":"donate","book_id":"784475"}' href="javascript:void(0)">捧场</a>
# <a class="monthTicket" data-sa-d='{"page_module":"readPage","click_name":"vote","book_id":"784475"}' href="javascript:void(0)">投票</a>
# <a class="chapterForum" data-sa-d='{"page_module":"readPage","click_name":"quanzi","book_id":"784475"}' href="http://forum.zongheng.com/220048.html" target="_blank">圈子</a>
# <a class="returntop" data-sa-d='{"page_module":"readPage","click_name":"top","book_id":"784475"}' href="#top">顶部</a>
# </div>
# </div>
# </div>
# <div class="h20-blank"></div>
# <!-- /大包 -->
# </div>
# <script async="" data-main="http://rcode.zongheng.com/v2018/js/map.min" defer="" src="http://rcode.zongheng.com/v2018/js/lib/require.min.js" type="text/javascript"></script>
# </body>
# </html>
