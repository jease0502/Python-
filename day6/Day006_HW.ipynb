# %% [markdown]
# # API 資料串接 - 以 知乎 API 實作範例
#
#
#
# * 了解知乎 API 使用方式與回傳內容
# * 撰寫程式存取 API 且添加標頭

# %% [markdown]
# ## 作業目標
#
# * 根據範例提供的 API ，完成以下問題：
#
#     1. 取出知乎問題發問時間
#     2. 取出第一筆與最後一筆回答的時間

# %% [markdown]
# ### 1. 取出知乎問題發問時間

# %%
# 1. 取出知乎問題發問時間
import json
import requests
headers = {'user-agent': 'my-app/0.0.1'}
r = requests.get('https://www.zhihu.com/api/v4/questions/55493026/answers',headers=headers)
response = r.text


data = json.loads(response)

for d in data['data']:
    print('發問時間:{:10d}'.format(d['created_time']))
# Out:
# 發問時間:1557824412
# 發問時間:1493707703
# 發問時間:1554085028
# 發問時間:1493693113
# 發問時間:1572318426

# %% [markdown]
# ### 2. 取出第一筆與最後一筆回答的時間

# %%
# 2. 取出第一筆與最後一筆回答的時間
creat_time = []
for d in data['data']:
    creat_time.append(d['created_time'])
print("第一筆資料:{:}".format(creat_time[0]))
print("最後一筆資料:{:}".format(creat_time[len(creat_time)-1]))
# Out:
# 第一筆資料:1557824412
# 最後一筆資料:1572318426
